# %%
record = { 
         "120001":{"P_name":"Dairy Milk Silk", "P_cat": "Choclates", "P_Quant": 20 ,"P_MRP": 50,"P_MFGY": 2020 ,"P_ExpM": 6 , "P_ExpY": 2022 },
         "120002": {"P_name": "Dairy Milk Crackle", "P_cat": "Choclates", "P_Quant": 40 ,"P_MRP": 25 ,"P_MFGY": 2021 ,"P_ExpM": 12 , "P_ExpY": 2022},
         "120003": {"P_name": "Dairy Milk Roasted Almonds", "P_cat": "Choclates", "P_Quant": 50 ,"P_MRP": 30 ,"P_MFGY": 2021 ,"P_ExpM": 12, "P_ExpY": 2022},
         "120004": {"P_name": "Dairy Milk Silk Bubbly", "P_cat": "Choclates", "P_Quant": 10,"P_MRP":100 ,"P_MFGY": 2021 ,"P_ExpM": 7 , "P_ExpY": 2023 },
         "120005": {"P_name": "Dairy Milk Cookie Crunch", "P_cat": "Choclates", "P_Quant": 20 ,"P_MRP": 35,"P_MFGY":2020,"P_ExpM":12 , "P_ExpY":2021 },
         "120006": {"P_name": "Dairy Milk Jello", "P_cat": "Choclates", "P_Quant":30,"P_MRP": 40 ,"P_MFGY": 2020 ,"P_ExpM": 7 , "P_ExpY": 2021 },
         "120007": {"P_name": "Dairy Milk Butterscotch", "P_cat": "Choclates", "P_Quant":10,"P_MRP":30 ,"P_MFGY":2021 ,"P_ExpM": 8 , "P_ExpY":2022 },
         "120008": {"P_name": "Dairy Milk Coffee", "P_cat": "Choclates", "P_Quant":15 ,"P_MRP": 45,"P_MFGY":2021 ,"P_ExpM":12 , "P_ExpY":2022 },
         "120009": {"P_name": "Crispello", "P_cat": "Choclates", "P_Quant": 30 ,"P_MRP": 40 ,"P_MFGY": 2021,"P_ExpM": 4 , "P_ExpY": 2023 },
         "120010": {"P_name": "Dairy Milk Oreo", "P_cat": "Choclates", "P_Quant": 45 ,"P_MRP": 55,"P_MFGY": 2020 ,"P_ExpM": 7 , "P_ExpY": 2022},
         "120011": {"P_name": "5 Star", "P_cat": "Choclates", "P_Quant": 50 ,"P_MRP": 10 ,"P_MFGY": 2021,"P_ExpM": 12 , "P_ExpY": 2023 },
         "120012": {"P_name": "5 Star Fuse", "P_cat": "Choclates", "P_Quant": 20 ,"P_MRP": 30 ,"P_MFGY":2021,"P_ExpM":12 , "P_ExpY":2022},
         "120013": {"P_name": "Perk", "P_cat": "Choclates", "P_Quant":100,"P_MRP": 10 ,"P_MFGY": 2021 ,"P_ExpM":12 , "P_ExpY":2023 },
         "120014": {"P_name": "Munch", "P_cat": "Choclates", "P_Quant": 100 ,"P_MRP":10 ,"P_MFGY":2021,"P_ExpM": 12 , "P_ExpY":2022 },
         "120015": {"P_name": "Kit-Kat", "P_cat": "Choclates", "P_Quant":200 ,"P_MRP":10 ,"P_MFGY":2021 ,"P_ExpM":12 , "P_ExpY":2023 },
         "120016": {"P_name": "Kurkure", "P_cat": "Snacks", "P_Quant":100 ,"P_MRP":10 ,"P_MFGY":2021 ,"P_ExpM":7 , "P_ExpY":2023 },
         "120017": {"P_name": "Lays", "P_cat": "Snacks", "P_Quant":100 ,"P_MRP":20 ,"P_MFGY":2021 ,"P_ExpM":2 , "P_ExpY":2024 },
         "120018": {"P_name": "Chataka-Pataka", "P_cat": "Snacks", "P_Quant":100 ,"P_MRP":5 ,"P_MFGY":2021 ,"P_ExpM":12 , "P_ExpY":2024},
         "120019": {"P_name": "Balaji Wafers", "P_cat": "Snacks", "P_Quant":200 ,"P_MRP":5 ,"P_MFGY":2021 ,"P_ExpM":6 , "P_ExpY":2024},
         "120020": {"P_name": "Bingo", "P_cat": "Snacks", "P_Quant":50 ,"P_MRP":5 ,"P_MFGY":2020 ,"P_ExpM":8 , "P_ExpY":2022},
         "120021": {"P_name": "Pringles", "P_cat": "Snacks", "P_Quant":75,"P_MRP":50 ,"P_MFGY":2021 ,"P_ExpM":12 , "P_ExpY":2024},
         "120022": {"P_name": "Pasta", "P_cat": "Snacks", "P_Quant":200 ,"P_MRP":25 ,"P_MFGY":2021 ,"P_ExpM":10 , "P_ExpY":2024},
         "120023": {"P_name": "Maggi", "P_cat": "Snacks", "P_Quant":200 ,"P_MRP":20 ,"P_MFGY":2021 ,"P_ExpM":1 , "P_ExpY":2024},
         "120024": {"P_name": "Poha", "P_cat": "Frozen food", "P_Quant":50 ,"P_MRP":40 ,"P_MFGY":2021 ,"P_ExpM":6 , "P_ExpY":2022},
         "120025": {"P_name": "Upma", "P_cat": "Frozen food", "P_Quant":50 ,"P_MRP":40 ,"P_MFGY":2021 ,"P_ExpM":8 , "P_ExpY":2022},
         "120026": {"P_name": "Pizza", "P_cat": "Frozen food", "P_Quant":50 ,"P_MRP":40 ,"P_MFGY":2021 ,"P_ExpM":5 , "P_ExpY":2022},
         "120027": {"P_name": "Tomato Ketchup", "P_cat": "Sauces", "P_Quant":100 ,"P_MRP":60 ,"P_MFGY":2021 ,"P_ExpM":6 , "P_ExpY":2022},
         "120028": {"P_name": "Tamarind Chutney", "P_cat": "Sauces", "P_Quant":50 ,"P_MRP":40 ,"P_MFGY":2021 ,"P_ExpM":8 , "P_ExpY":2022},
         "120029": {"P_name": "Green chilli sauce", "P_cat": "Sauces", "P_Quant":50 ,"P_MRP":20 ,"P_MFGY":2021 ,"P_ExpM":10 , "P_ExpY":2022},
         "120030": {"P_name": "Red chilli sauce", "P_cat": "Sauces", "P_Quant":50 ,"P_MRP":20 ,"P_MFGY":2021 ,"P_ExpM":12 , "P_ExpY":2022}
}

# %%
import json
js = json.dumps(record)

# %%
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
fd = open("record.json",'r')
txt = fd.read()
fd.close()

record = json.loads(txt)

# %%
txt
# Out:
# '{"120001": {"P_name": "Dairy Milk Silk", "P_cat": "Choclates", "P_Quant": 20, "P_MRP": 50, "P_MFGY": 2020, "P_ExpM": 6, "P_ExpY": 2022}, "120002": {"P_name": "Dairy Milk Crackle", "P_cat": "Choclates", "P_Quant": 40, "P_MRP": 25, "P_MFGY": 2021, "P_ExpM": 12, "P_ExpY": 2022}, "120003": {"P_name": "Dairy Milk Roasted Almonds", "P_cat": "Choclates", "P_Quant": 50, "P_MRP": 30, "P_MFGY": 2021, "P_ExpM": 12, "P_ExpY": 2022}, "120004": {"P_name": "Dairy Milk Silk Bubbly", "P_cat": "Choclates", "P_Quant": 10, "P_MRP": 100, "P_MFGY": 2021, "P_ExpM": 7, "P_ExpY": 2023}, "120005": {"P_name": "Dairy Milk Cookie Crunch", "P_cat": "Choclates", "P_Quant": 20, "P_MRP": 35, "P_MFGY": 2020, "P_ExpM": 12, "P_ExpY": 2021}, "120006": {"P_name": "Dairy Milk Jello", "P_cat": "Choclates", "P_Quant": 30, "P_MRP": 40, "P_MFGY": 2020, "P_ExpM": 7, "P_ExpY": 2021}, "120007": {"P_name": "Dairy Milk Butterscotch", "P_cat": "Choclates", "P_Quant": 10, "P_MRP": 30, "P_MFGY": 2021, "P_ExpM": 8, "P_ExpY": 2022}, "
# ...

# %%
p_id = str(input("Enter product id:"))
name = str(input("Enter product name:"))
cat = str(input("Enter product category: "))
mrp = int(input("Enter product price:"))
qn = int(input("Enter product quantity:"))
mfgy = int(input("Enter manufacturing year of product :"))
expm = int(input("Enter product expiry month:"))
expy = int(input("Enter product expiry year:"))
record[p_id] = {"P_name": name,"P_cat":cat,"P_Quant": qn,"P_MRP":mrp,"P_MFGY":mfgy,"P_ExpM":expm,"P_ExpY":expy }

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:120031
# Enter product name:Bisleri
# Enter product category: Water
# Enter product price:20
# Enter product quantity:50
# Enter manufacturing year of product :2021
# Enter product expiry month:12
# Enter product expiry year:2022

# %%
record
# Out:
# {'120001': {'P_ExpM': 6,
#   'P_ExpY': 2022,
#   'P_MFGY': 2020,
#   'P_MRP': 50,
#   'P_Quant': 20,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Silk'},
#  '120002': {'P_ExpM': 12,
#   'P_ExpY': 2022,
#   'P_MFGY': 2021,
#   'P_MRP': 25,
#   'P_Quant': 40,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Crackle'},
#  '120003': {'P_ExpM': 12,
#   'P_ExpY': 2022,
#   'P_MFGY': 2021,
#   'P_MRP': 30,
#   'P_Quant': 50,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Roasted Almonds'},
#  '120004': {'P_ExpM': 7,
#   'P_ExpY': 2023,
#   'P_MFGY': 2021,
#   'P_MRP': 100,
#   'P_Quant': 10,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Silk Bubbly'},
#  '120005': {'P_ExpM': 12,
#   'P_ExpY': 2021,
#   'P_MFGY': 2020,
#   'P_MRP': 35,
#   'P_Quant': 20,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Cookie Crunch'},
#  '120006': {'P_ExpM': 7,
#   'P_ExpY': 2021,
#   'P_MFGY': 2020,
#   'P_MRP': 40,
#   'P_Quant': 30,
#   'P_cat': 'Choclates',
# ...

# %%
del_pid = int(input("Enter the product's id which is to be deleted: "))
# Out:
# Enter the product's id which is to be deleted: 120031

# %%
del_pid = str(del_pid)

# %%
del record[del_pid]

# %%
record
# Out:
# {'120001': {'P_ExpM': 6,
#   'P_ExpY': 2022,
#   'P_MFGY': 2020,
#   'P_MRP': 50,
#   'P_Quant': 20,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Silk'},
#  '120002': {'P_ExpM': 12,
#   'P_ExpY': 2022,
#   'P_MFGY': 2021,
#   'P_MRP': 25,
#   'P_Quant': 40,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Crackle'},
#  '120003': {'P_ExpM': 12,
#   'P_ExpY': 2022,
#   'P_MFGY': 2021,
#   'P_MRP': 30,
#   'P_Quant': 50,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Roasted Almonds'},
#  '120004': {'P_ExpM': 7,
#   'P_ExpY': 2023,
#   'P_MFGY': 2021,
#   'P_MRP': 100,
#   'P_Quant': 10,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Silk Bubbly'},
#  '120005': {'P_ExpM': 12,
#   'P_ExpY': 2021,
#   'P_MFGY': 2020,
#   'P_MRP': 35,
#   'P_Quant': 20,
#   'P_cat': 'Choclates',
#   'P_name': 'Dairy Milk Cookie Crunch'},
#  '120006': {'P_ExpM': 7,
#   'P_ExpY': 2021,
#   'P_MFGY': 2020,
#   'P_MRP': 40,
#   'P_Quant': 30,
#   'P_cat': 'Choclates',
# ...
